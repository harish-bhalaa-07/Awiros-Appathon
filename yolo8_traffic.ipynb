# %%
from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="google_colab_config.yaml", epochs=5,imgsz=160,batch=4)  # train the model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Works\awiros\yolo8_traffic.ipynb Cell 1 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from ultralytics import YOLO
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> # Load a model
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> model = YOLO("yolov8n.yaml")  # build a new model from scratch
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
from PIL import Image

# %%
results = model('./th.jpg')
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')
# Out:
# image 1/1 d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\th.jpg: 160x160 1 truck, 17.4ms
# Speed: 1.4ms preprocess, 17.4ms inference, 5.1ms postprocess per image at shape (1, 3, 160, 160)

# %%
from ultralytics import YOLO

# %%
model=YOLO(model='./runs/detect/train2/weights/best.pt')
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\labels\train.cache... 120 images, 0 backgrounds, 0 corrupt: 100%|██████████| 120/120 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
#                    all        120        133      0.984      0.939      0.986      0.792
# Speed: 0.5ms preprocess, 7.8ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs\detect\val4
# array([    0.79174])

# %%
import torch

# %%
source = './Heavy Load truck hill climbing _ Ashok Leyaland _ TATA _ Bharat Benz _ Heavy Load.mp4'

# Run inference on the source
results = model(source, stream=True)

# %%
import cv2

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\TrainYolov8CustomDataset.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> cv2.imshow(results,mat='MatLike')
#
# File c:\Users\Velan\anaconda3\envs\pytorchgpu\Lib\site-packages\ultralytics\utils\patches.py:55, in imshow(winname, mat)
#      47 def imshow(winname: str, mat: np.ndarray):
#      48     """
#      49     Displays an image in the specified window.
#      50
#    (...)
#      53         mat (np.ndarray): Image to be shown.
#      54     """
# ...

# %%
H, W, _ = frame.shape()
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\TrainYolov8CustomDataset.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> H, W, _ = frame.shape()
#       <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))
# ...

# %%
model=YOLO(model='./runs/detect/train2/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\TrainYolov8CustomDataset.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> model=YOLO(model='./runs/detect/train2/weights/best.pt')
#
# NameError: name 'YOLO' is not defined

# %%
import cv2
video_path = "./Heavy Load truck hill climbing _ Ashok Leyaland _ TATA _ Bharat Benz _ Heavy Load.mp4"

cap = cv2.VideoCapture(video_path)

#Save Video

# %%
while cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()
        
        if success:
                # Run YOLOv8 inference on the frame
          results = model(frame)

    # Visualize the results on the frame
          annotated_frame = results[0].plot()

    # Display the annotated frame
          cv2.imshow("YOLOv8 Inference", annotated_frame)
            

    # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
    # Break the loop if the end of the video is reached
            break

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' codec for MP4
output_video = cv2.VideoWriter('output_video.mp4', fourcc, 30.0, (640, 480))  # You can specify the frame size

# %%
while cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()
        
        if success:
                results = model(frame)
                annotated_frame = results[0].plot()
                cv2.imshow('Annotated Frame', annotated_frame)
                output_video.write(annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
        # Break the loop if the end of the video is reached
                break

# %%
output_video.release()
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('./runs/detect/train2/weights/best.pt')

# Open the video file
video_path = "./Heavy Load truck hill climbing _ Ashok Leyaland _ TATA _ Bharat Benz _ Heavy Load.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        

        # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
            break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 160x96 1 truck, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 5.4ms postprocess per image at shape (1, 3, 160, 96)

# %%
pip install supervision
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000180B5FC4990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/supervision/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000180B934F290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/supervision/
# ...

# %%
import supervision as sv
import numpy as np
from ultralytics import YOLO

VIDEO_PATH = './Heavy Load truck hill climbing _ Ashok Leyaland _ TATA _ Bharat Benz _ Heavy Load.mp4'

model = YOLO("./runs/detect/train2/weights/best.pt")

video_info = sv.VideoInfo.from_video_path(VIDEO_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\TrainYolov8CustomDataset.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> import supervision as sv
#       <a href='vscode-notebook-cell:/d%3A/awiros/train-yolov8-custom-dataset-step-by-step-guide-master/train-yolov8-custom-dataset-step-by-step-guide-master/google_colab/TrainYolov8CustomDataset.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
# ...

# %%
from ultralytics import YOLO

# %%
model=YOLO(model='./runs/detect/train2/weights/best.pt')

# %%
source = './y2mate.com - Tamilnadu heavy loaded trucktamilnadu shorts youtubeshorts_1080p.mp4'

# Run inference on the source
results = model(source, show=True, save=True,boxes=True,vid_stride=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/514) d:\awiros\train-yolov8-custom-dataset-step-by-step-guide-master\train-yolov8-custom-dataset-step-by-step-guide-master\google_colab\y2mate.com - Tamilnadu heavy loaded trucktamilnadu shorts youtubeshorts_1080p.mp4: 160x96 1 truck, 60.1ms
# ...

# %%
import torch

# Instantiate your model. This is just a regular PyTorch model that will be exported in the following steps.
model = yolov8n.pt
# Evaluate the model to switch some operations from training mode to inference.
model.eval()
# Create dummy input for the model. It will be used to run the model inside export function.
dummy_input = torch.randn(1, 3, 224, 224)
# Call the export function
torch.onnx.export(model, (dummy_input, ), 'model.onnx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Works\awiros\yolo8_traffic.ipynb Cell 30 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> import torch
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> # Instantiate your model. This is just a regular PyTorch model that will be exported in the following steps.
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> model = yolov8n.pt
#
# ModuleNotFoundError: No module named 'torch'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom trained model

# Export the model
model.export(format='onnx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Works\awiros\yolo8_traffic.ipynb Cell 31 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> from ultralytics import YOLO
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> # Load a model
#       <a href='vscode-notebook-cell:/d%3A/Works/awiros/yolo8_traffic.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> model = YOLO('yolov8n.pt')  # load an official model
#
# ModuleNotFoundError: No module named 'ultralytics'
